# %% [markdown]
# ###  Lab Report Tasks:
# Current readings are stored in a list. Engineers want to calculate the square of each value for power loss calculation.
# Print the square of each current reading using formula I².
# 	Make a list of current values, loop and multiply each by itself.

# %%
# List of current readings (in Amperes)
current_readings = [2, 3, 4, 5]  # Example values

# Calculate and print the square of each reading
print("Current readings squared (I²):")
for I in current_readings:
    power_loss = I * I  # I²
    print(f"Current: {I} A → I²: {power_loss} A²")
# Out:
# Current readings squared (I²):
# Current: 2 A → I²: 4 A²
# Current: 3 A → I²: 9 A²
# Current: 4 A → I²: 16 A²
# Current: 5 A → I²: 25 A²
